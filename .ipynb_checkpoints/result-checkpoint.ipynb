# %%
# %pylab inline
from scipy.optimize import curve_fit
import pandas as pd
import seaborn as sns
import numpy as np
import scipy 
import matplotlib.pyplot as plt
import matplotlib.style as style
import itertools
from sklearn.linear_model import LogisticRegression
import sys

import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_home = pd.read_excel('df_both_seasons_home.xlsx')
df_away = pd.read_excel('df_both_seasons_away.xlsx')

# %%
df_home.columns
# Out:
# Index(['Unnamed: 0', 'Day', 'Month', 'Year', 'HomeTeam', 'AwayTeam', 'FTHG',
#        'HS', 'AS', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR',
#        'AR', 'HTGDIFF', 'ATGDIFF', 'AVGHTGDIFF', 'AVGFTHG'],
#       dtype='object')

# %%
df_away.columns
# Out:
# Index(['Unnamed: 0', 'Day', 'Month', 'Year', 'HomeTeam', 'AwayTeam', 'FTAG',
#        'HS', 'AS', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR',
#        'AR', 'HTGDIFF', 'ATGDIFF', 'AVGATGDIFF', 'AVGFTAG'],
#       dtype='object')

# %%
cols_to_use = df_home.columns.difference(df_away.columns)

# %%
cols_to_use
# Out:
# Index(['AVGFTHG', 'AVGHTGDIFF', 'FTHG'], dtype='object')

# %%
df_both = pd.merge(df_away, df_home[cols_to_use], left_index=True, right_index=True, how='outer')

# %%
df_both.columns.values
# Out:
# array(['Unnamed: 0', 'Day', 'Month', 'Year', 'HomeTeam', 'AwayTeam',
#        'FTAG', 'HS', 'AS', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY',
#        'AY', 'HR', 'AR', 'HTGDIFF', 'ATGDIFF', 'AVGATGDIFF', 'AVGFTAG',
#        'AVGFTHG', 'AVGHTGDIFF', 'FTHG'], dtype=object)

# %%
df_both['HW'],  df_both['HL'],  df_both['D'], df_both['AW'],  df_both['AL'] = [0, 0, 0, 0, 0]

# %%
del df_both['Unnamed: 0']

# %%
df_both.columns
# Out:
# Index(['Day', 'Month', 'Year', 'HomeTeam', 'AwayTeam', 'FTAG', 'HS', 'AS',
#        'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'HTGDIFF',
#        'ATGDIFF', 'AVGATGDIFF', 'AVGFTAG', 'AVGFTHG', 'AVGHTGDIFF', 'FTHG',
#        'HW', 'HL', 'D', 'AW', 'AL'],
#       dtype='object')

# %%
df_both = df_both.reindex(columns = ['Day', 'Month', 'Year', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'HW', 'HL','D', 'AW', 'AL',
       'HTGDIFF', 'ATGDIFF', 'AVGATGDIFF', 'AVGFTAG','AVGFTHG', 'AVGHTGDIFF'])

# %%
for i in range(0, len(df_both)):
    if df_both['FTHG'][i] > df_both['FTAG'][i]:
        df_both['HW'][i], df_both['AL'][i] = 1, 1 
    elif df_both['FTHG'][i] == df_both['FTAG'][i]:
        df_both['D'][i] = 1
    elif df_both['FTHG'][i] < df_both['FTAG'][i]:
        df_both['AW'][i], df_both['HL'][i] = 1, 1

# %%
df_both
# Out:
#      Day  Month  Year       HomeTeam       AwayTeam  FTHG  FTAG  HW  HL  D  \
# 0     18     12  2019     Leverkusen         Hertha     0     1   0   1  0
# 1     18     12  2019  Ein Frankfurt        FC Koln     2     4   0   1  0
# 2     18     12  2019       Freiburg  Bayern Munich     1     3   0   1  0
# 3     18     12  2019     M'gladbach      Paderborn     2     0   1   0  0
# 4     18     12  2019      Wolfsburg     Schalke 04     1     1   0   0  1
# ..   ...    ...   ...            ...            ...   ...   ...  ..  .. ..
# 445    9      1  2018       Nurnberg          Mainz     1     1   0   0  1
# 446    9      1  2018       Augsburg     M'gladbach     1     1   0   0  1
# 447    9      1  2018  Ein Frankfurt  Werder Bremen     3     2   1   0  0
# 448    9      1  2018     Hoffenheim       Freiburg     1     1   0   0  1
# 449    9      1  2018     Leverkusen      Wolfsburg     0     3   0   1  0
#
# ...

# %%
df_both.to_excel('both.xlsx')
